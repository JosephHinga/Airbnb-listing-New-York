# %% [markdown]
# Python Project EDA & Data Viz - AirBnB Listing 2025 (New York)
#
# steps
#
# 1.importing all dependenices (lib)
#
# 2.loading datasets
#
# 3.initial exploration
#
# 4.Data cleaning
#
# 5.Data Analysis

# %% [markdown]
#  1. Importing libraries

# %%
from ast import increment_lineno
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
#  2.Loading Datasets

# %%
data= pd.read_csv('/content/dataset.csv.csv')

# %% [markdown]
# 3.Initial Exploration

# %%
data.head()
# Out:
#              id                                               name  \
# 0  1.312228e+06         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1  4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2  9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3  3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4  4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...
#
#        host_id           host_name neighbourhood_group       neighbourhood  \
# 0    7130382.0              Walter            Brooklyn        Clinton Hill
# 1   51501835.0            Jeniffer           Manhattan      Hell's Kitchen
# 2  528871354.0              Joshua           Manhattan             Chelsea
# 3   19902271.0  John And Catherine           Manhattan  Washington Heights
# 4   61391963.0      Stay With Vibe           Manhattan         Murray Hill
#
#     latitude  longitude        room_type  price  ...  last_review  \
# 0  40.683710 -73.964610     Private room   55.0  ...     20/12/15
# 1  40.766610 -73.988100  Entire home/apt  144.0  ...     01/05/23
# 2  40.750764 -73.994605  Entire home/apt  187.0  ...     18/12/23
# 3  40.835600 -73.942500     Private room  120.0  ...     17/09/23
# 4  40.751120 -73.978600  Entire home/apt   85.0  ...     03/12/23
#
#    reviews_per_month calculated_host_listings_count  availability_365  \
# 0               0.03                            1.0               0.0
# 1               0.24                          139.0             364.0
# 2               1.67                            1.0             343.0
# 3               1.38                            2.0             363.0
# 4               0.24                          133.0             335.0
#
#    number_of_reviews_ltm     license  rating bedrooms beds          baths
# 0                    0.0  No License       5        1  1.0  Not specified
# 1                    2.0  No License    4.67        2  1.0              1
# 2                    6.0      Exempt    4.17        1  2.0              1
# 3                   12.0  No License    4.64        1  1.0              1
# 4                    3.0  No License    4.91   Studio  1.0              1
#
# [5 rows x 22 columns]

# %%
#last 5 rows
data.tail()
# Out:
#               id                                               name  \
# 5075  52648068.0  Rental unit in New York · ★4.69 · 2 bedrooms ·...
# 5076  33664484.0  Home in Queens · ★4.94 · 3 bedrooms · 4 beds ·...
# 5077  51702923.0  Townhouse in Brooklyn · ★5.0 · 3 bedrooms · 3 ...
# 5078  51205263.0  Home in Queens · ★4.91 · 1 bedroom · 1 bed · 1...
# 5079  34142214.0          Rental unit in The Bronx · ★4.63 · 1 bedr
#
#           host_id       host_name neighbourhood_group       neighbourhood  \
# 5075  426099783.0          Melvin           Manhattan  Washington Heights
# 5076  157301360.0  Dalia & Marina              Queens   Kew Gardens Hills
# 5077     327439.0           Emily            Brooklyn        Williamsburg
# 5078  414317909.0        Marshawn              Queens       East Elmhurst
# 5079          NaN             NaN                 NaN                 NaN
#
#       latitude  longitude        room_type  price  ...  last_review  \
# 5075  40.85478  -73.93879  Entire home/apt  109.0  ...     09/11/23
# 5076  40.72807  -73.82073  Entire home/apt  325.0  ...     24/08/23
# 5077  40.71831  -73.96143  Entire home/apt  800.0  ...     04/12/22
# 5078  40.76298  -73.86181     Private room  328.0  ...     08/10/23
# 5079       NaN        NaN              NaN    NaN  ...          NaN
#
#       reviews_per_month calculated_host_listings_count  availability_365  \
# 5075               0.48                            1.0               0.0
# 5076               0.94                            2.0             270.0
# 5077               0.17                            1.0             276.0
# 5078               3.55                            1.0             180.0
# 5079                NaN                            NaN               NaN
#
#       number_of_reviews_ltm     license  rating bedrooms beds baths
# 5075                    6.0  No License    4.69        2  3.0     1
# 5076                    5.0  No License    4.94        3  4.0   1.5
# 5077                    0.0  No License       5        3  3.0   3.5
# 5078                   20.0  No License    4.91        1  1.0     1
# 5079                    NaN         NaN     NaN      NaN  NaN   NaN
#
# [5 rows x 22 columns]

# %%
# shape of the data
data.shape
# Out:
# (5080, 22)

# %%
# data information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5080 entries, 0 to 5079
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              5080 non-null   float64
#  1   name                            5080 non-null   object
#  2   host_id                         5079 non-null   float64
#  3   host_name                       5079 non-null   object
#  4   neighbourhood_group             5079 non-null   object
#  5   neighbourhood                   5079 non-null   object
#  6   latitude                        5079 non-null   float64
#  7   longitude                       5079 non-null   float64
#  8   room_type                       5079 non-null   object
#  9   price                           5079 non-null   float64
#  10  minimum_nights                  5079 non-null   float64
#  11  number_of_reviews               5079 non-null   float64
#  12  last_review                     5079 non-null   object
#  13  reviews_per_month               5079 non-null   float64
#  14  calculated_host_listings_count  5079 non-null   float64
#  15  availability_365                5079 non-null   float64
#  16  number_of_reviews_ltm           5079 non-null   float64
#  17  license                         5079 non-null   object
#  18  rating                          5079 non-null   object
#  19  bedrooms                        5079 non-null   object
#  20  beds                            5079 non-null   float64
#  21  baths                           5079 non-null   object
# dtypes: float64(12), object(10)
# memory usage: 873.3+ KB

# %%
# Statistical summary of the data
data.describe()
# Out:
#                  id       host_id     latitude    longitude          price  \
# count  5.080000e+03  5.079000e+03  5079.000000  5079.000000    5079.000000
# mean   2.950738e+17  1.819393e+08    40.726800   -73.945784     220.960032
# std    3.897772e+17  1.729947e+08     0.058335     0.059588    1457.715441
# min    7.064000e+03  2.234000e+03    40.500314   -74.249840      10.000000
# 25%    2.957079e+07  2.377272e+07    40.686040   -73.985800      83.000000
# 50%    4.975470e+07  1.265381e+08    40.728540   -73.954700     128.000000
# 75%    7.110000e+17  3.277520e+08    40.762085   -73.922798     200.000000
# max    1.050000e+18  5.489914e+08    40.910620   -73.726730  100000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count     5079.000000        5079.000000        5079.000000
# mean        30.045285          36.364048           1.116970
# std         49.447534          67.976715           1.487078
# min          1.000000           1.000000           0.010000
# 25%         30.000000           3.000000           0.180000
# 50%         30.000000          12.000000           0.540000
# 75%         30.000000          40.000000           1.600000
# max       1250.000000        1865.000000          37.000000
#
#        calculated_host_listings_count  availability_365  \
# count                     5079.000000       5079.000000
# mean                        19.097263        196.792282
# std                         71.498464        139.347249
# min                          1.000000          0.000000
# 25%                          1.000000         64.000000
# 50%                          2.000000        192.000000
# 75%                          6.000000        350.000000
# max                        713.000000        365.000000
#
#        number_of_reviews_ltm         beds
# count            5079.000000  5079.000000
# mean                9.033077     1.719236
# std                14.880477     1.182752
# min                 0.000000     1.000000
# 25%                 0.000000     1.000000
# 50%                 3.000000     1.000000
# 75%                12.000000     2.000000
# max               303.000000    21.000000

# %% [markdown]
# 4. Data Cleaning

# %%
# missing values
data.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           1
# host_name                         1
# neighbourhood_group               1
# neighbourhood                     1
# latitude                          1
# longitude                         1
# room_type                         1
# price                             1
# minimum_nights                    1
# number_of_reviews                 1
# last_review                       1
# reviews_per_month                 1
# calculated_host_listings_count    1
# availability_365                  1
# number_of_reviews_ltm             1
# license                           1
# rating                            1
# bedrooms                          1
# beds                              1
# baths                             1
# dtype: int64

# %%
# dropping missing values
data.dropna(inplace=True)

# %%
# after dropping the missing values
data.shape
# Out:
# (5079, 22)

# %%
# checking the duplicate records
data[data.duplicated()]
# Out:
#               id                                               name  \
# 6   4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 7   9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 8   3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 9   4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# 10  4.958498e+07  Rental unit in New York · ★5.0 · 1 bedroom · 1...
#
#         host_id           host_name neighbourhood_group       neighbourhood  \
# 6    51501835.0            Jeniffer           Manhattan      Hell's Kitchen
# 7   528871354.0              Joshua           Manhattan             Chelsea
# 8    19902271.0  John And Catherine           Manhattan  Washington Heights
# 9    61391963.0      Stay With Vibe           Manhattan         Murray Hill
# 10   51501835.0            Jeniffer           Manhattan      Hell's Kitchen
#
#      latitude  longitude        room_type  price  ...  last_review  \
# 6   40.766610 -73.988100  Entire home/apt  144.0  ...     01/05/23
# 7   40.750764 -73.994605  Entire home/apt  187.0  ...     18/12/23
# 8   40.835600 -73.942500     Private room  120.0  ...     17/09/23
# 9   40.751120 -73.978600  Entire home/apt   85.0  ...     03/12/23
# 10  40.759950 -73.992960  Entire home/apt  115.0  ...     29/07/23
#
#     reviews_per_month calculated_host_listings_count  availability_365  \
# 6                0.24                          139.0             364.0
# 7                1.67                            1.0             343.0
# 8                1.38                            2.0             363.0
# 9                0.24                          133.0             335.0
# 10               0.16                          139.0             276.0
#
#     number_of_reviews_ltm     license  rating bedrooms beds baths
# 6                     2.0  No License    4.67        2  1.0     1
# 7                     6.0      Exempt    4.17        1  2.0     1
# 8                    12.0  No License    4.64        1  1.0     1
# 9                     3.0  No License    4.91   Studio  1.0     1
# 10                    2.0  No License       5        1  1.0     1
#
# [5 rows x 22 columns]

# %%
# Duplicate rows
data.duplicated().sum()
# Out:
# np.int64(5)

# %%
#Deleting duplicate rows
data.drop_duplicates(inplace=True)

# %%
# Checking the duplicates after deleting
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# type casting
# changing data types

data.dtypes

data['id'] = data['id'].astype(object)
data.dtypes

data['host_id'] = data['host_id'].astype(object)
data.dtypes
# Out:
# id                                 object
# name                               object
# host_id                            object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                              float64
# baths                              object
# dtype: object

# %% [markdown]
# EDA

# %% [markdown]
# 5.Data Analysis

# %% [markdown]
#  UNIVARIATE ANALYSIS

# %%
# Identifying outliers in price

df = data[data['price'] < 1500].copy()


sns.boxplot(data=df,x='price')
# Out:
# <Axes: xlabel='price'>

# %%
 # Price Distribution

 plt.figure(figsize=(8,5))
 sns.histplot(data=df, x="price", bins=100)
 plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df.dtypes
# Out:
# id                                 object
# name                               object
# host_id                            object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                              float64
# baths                              object
# dtype: object

# %%
#Price distribuion
plt.figure(figsize=(6, 3))
sns.histplot(data=df, x='availability_365')
plt.title('availability_365 Distribuition')
plt.ylabel("Frequency")
plt.show()

# %%
data.dtypes
# Out:
# id                                 object
# name                               object
# host_id                            object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                              float64
# baths                              object
# dtype: object

# %%
df.groupby(by='neighbourhood_group')['price'].mean()
# Out:
# neighbourhood_group
# Bronx            100.950000
# Brooklyn         148.772542
# Manhattan        230.591716
# Queens           122.443902
# Staten Island    140.304878
# Name: price, dtype: float64

# %%
df.groupby(by='neighbourhood_group')['price'].mean()
# Out:
# neighbourhood_group
# Bronx            100.950000
# Brooklyn         148.772542
# Manhattan        230.591716
# Queens           122.443902
# Staten Island    140.304878
# Name: price, dtype: float64

# %% [markdown]
# Feature Engineering

# %%
df.head()
# Out:
#                      id                                               name  \
# 0             1312228.0         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1            45277537.0  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2  971000000000000000.0  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3             3857863.0  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4            40896611.0  Condo in New York · ★4.91 · Studio · 1 bed · 1...
#
#        host_id           host_name neighbourhood_group       neighbourhood  \
# 0    7130382.0              Walter            Brooklyn        Clinton Hill
# 1   51501835.0            Jeniffer           Manhattan      Hell's Kitchen
# 2  528871354.0              Joshua           Manhattan             Chelsea
# 3   19902271.0  John And Catherine           Manhattan  Washington Heights
# 4   61391963.0      Stay With Vibe           Manhattan         Murray Hill
#
#     latitude  longitude        room_type  price  ...  last_review  \
# 0  40.683710 -73.964610     Private room   55.0  ...     20/12/15
# 1  40.766610 -73.988100  Entire home/apt  144.0  ...     01/05/23
# 2  40.750764 -73.994605  Entire home/apt  187.0  ...     18/12/23
# 3  40.835600 -73.942500     Private room  120.0  ...     17/09/23
# 4  40.751120 -73.978600  Entire home/apt   85.0  ...     03/12/23
#
#    reviews_per_month calculated_host_listings_count  availability_365  \
# 0               0.03                            1.0               0.0
# 1               0.24                          139.0             364.0
# 2               1.67                            1.0             343.0
# 3               1.38                            2.0             363.0
# 4               0.24                          133.0             335.0
#
#    number_of_reviews_ltm     license  rating bedrooms beds          baths
# 0                    0.0  No License       5        1  1.0  Not specified
# 1                    2.0  No License    4.67        2  1.0              1
# 2                    6.0      Exempt    4.17        1  2.0              1
# 3                   12.0  No License    4.64        1  1.0              1
# 4                    3.0  No License    4.91   Studio  1.0              1
#
# [5 rows x 22 columns]

# %%
# price per bed
df["price per bed"] = df["price"]/df["beds"]

# checking the new column created
df.head()
# Out:
#                      id                                               name  \
# 0             1312228.0         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1            45277537.0  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2  971000000000000000.0  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3             3857863.0  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4            40896611.0  Condo in New York · ★4.91 · Studio · 1 bed · 1...
#
#        host_id           host_name neighbourhood_group       neighbourhood  \
# 0    7130382.0              Walter            Brooklyn        Clinton Hill
# 1   51501835.0            Jeniffer           Manhattan      Hell's Kitchen
# 2  528871354.0              Joshua           Manhattan             Chelsea
# 3   19902271.0  John And Catherine           Manhattan  Washington Heights
# 4   61391963.0      Stay With Vibe           Manhattan         Murray Hill
#
#     latitude  longitude        room_type  price  ...  reviews_per_month  \
# 0  40.683710 -73.964610     Private room   55.0  ...               0.03
# 1  40.766610 -73.988100  Entire home/apt  144.0  ...               0.24
# 2  40.750764 -73.994605  Entire home/apt  187.0  ...               1.67
# 3  40.835600 -73.942500     Private room  120.0  ...               1.38
# 4  40.751120 -73.978600  Entire home/apt   85.0  ...               0.24
#
#    calculated_host_listings_count availability_365  number_of_reviews_ltm  \
# 0                             1.0              0.0                    0.0
# 1                           139.0            364.0                    2.0
# 2                             1.0            343.0                    6.0
# 3                             2.0            363.0                   12.0
# 4                           133.0            335.0                    3.0
#
#       license  rating  bedrooms beds          baths price per bed
# 0  No License       5         1  1.0  Not specified          55.0
# 1  No License    4.67         2  1.0              1         144.0
# 2      Exempt    4.17         1  2.0              1          93.5
# 3  No License    4.64         1  1.0              1         120.0
# 4  No License    4.91    Studio  1.0              1          85.0
#
# [5 rows x 23 columns]

# %%
# average price per bed
df.groupby(by='neighbourhood_group')['price per bed'].mean()
# Out:
# neighbourhood_group
# Bronx             74.340303
# Brooklyn          96.193366
# Manhattan        153.924420
# Queens            79.517877
# Staten Island     66.854675
# Name: price per bed, dtype: float64

# %% [markdown]
# **Bivariate analysis**

# %%
# Bivariate analysis -one variable dependency in another variable

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'rating',
#        'bedrooms', 'beds', 'baths', 'price per bed'],
#       dtype='object')

# %%
# price dependency on neighbourhood
sns.barplot(data=df, x='neighbourhood_group', y='price', hue='room_type')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %%
# number of reviews and price rel
plt.figure(figsize=(8, 5))
plt.title("Locality and Review Dependency")
sns.scatterplot(data=df, x='number_of_reviews', y='price', hue='neighbourhood_group')
plt.show()

# %%
df.dtypes
# Out:
# id                                 object
# name                               object
# host_id                            object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                              float64
# baths                              object
# price per bed                     float64
# dtype: object

# %%
sns.pairplot(data=df, vars=['price', 'minimum_nights', 'number_of_reviews', 'availability_365'], hue='room_type')

# %%
#Geographical Distribution of AirBnb Listing
plt.figure(figsize=(10, 7))
sns.scatterplot(data=df, x='longitude', y='latitude', hue='room_type')
plt.title("Geographical Distribution of AirBnb Listing")
plt.show()

# %%
df.dtypes
# Out:
# id                                 object
# name                               object
# host_id                            object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                              float64
# baths                              object
# price per bed                     float64
# dtype: object

# %%
#heat map - correlation of one variable with others for numerical column

corr = df[['latitude', 'longitude', 'price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'availability_365', 'beds']].corr()
corr

plt.figure(figsize=(8, 6))
sns.heatmap(data=corr, annot=True)
# Out:
# <Axes: >
